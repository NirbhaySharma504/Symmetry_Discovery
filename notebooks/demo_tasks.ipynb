# %% [markdown]
# # GSoC 2026 - Discovery of Hidden Symmetries and Conservation Laws
#
# **Task 1**: Dataset Preparation (rotate MNIST by 30 deg steps) + VAE Training
# **Task 2**: Supervised Symmetry Discovery (MLP learns rotation in latent space)
# **Task 3a**: Unsupervised Symmetry Discovery - binary 0/1 (paper approach)
# **Task 3b**: Unsupervised Symmetry Discovery - full 0-9 (original extension)
#
# This notebook explicitly sets all hyperparameters natively before training/inferencing a step so reviewers can easily change them!

# %%
# ================================
# Environment Setup Cell
# ================================

import os
import sys
import subprocess

# ---- 1. Ensure project root is in path ----
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

# ---- 2. Install required packages (safe for notebook users) ----
def install_if_missing(package):
    try:
        __import__(package)
    except ImportError:
        print(f"Installing {package}...")
        subprocess.check_call([sys.executable, "-m", "pip", "install", package])

install_if_missing("gdown")

import gdown
import torch
import matplotlib.pyplot as plt
import numpy as np

# ---- 3. Import project modules ----
from src.utils import DEVICE, CKPT, FIGS, show_cached_figure
from src.dataset import load_data, make_loader
from src.models import VAE, RotationMLP, LatentClassifier, SymmetryGenerator
from src.train import (
    train_vae, encode_dataset, train_rotation_mlp,
    train_classifier, train_symmetry_generator
)
from src.evaluate import (
    visualise_supervised, visualise_unsupervised,
    plot_symmetry_paths, visualise_rotated_samples,
    visualise_latent_space, visualise_reconstructions,
    visualise_rotation_trajectories, visualise_reconstructions_full
)

# ---- 4. Download weights if not already present ----
def download_weights_if_needed(download_dir=CKPT):
    os.makedirs(download_dir, exist_ok=True)

    # Check if folder already has files
    if len(os.listdir(download_dir)) > 0:
        print(f"✅ Weights already present in {download_dir}, skipping download.")
        return

    print(f"Downloading weights to {download_dir}...")

    url = "https://drive.google.com/drive/folders/1BZoCcW8YzKFzHbMExrWTXE_I3ctyaidX"
    
    gdown.download_folder(
        url=url,
        output=str(download_dir),
        quiet=False,
        use_cookies=False
    )

    print("✅ Download complete.")

# Run it
download_weights_if_needed()

# ---- 5. Device info ----
print(f"Using device: {DEVICE}")
# Out:
# Downloading weights to /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/checkpoints...
# Retrieving folder contents
# Processing file 1rG1DICUX-DPshGi3A5XB0GhwKYTEwx4K clf10_8d_lb.pth
# Processing file 1Gb7hedTwVnGTXgNITmp2Em3Tjr52rIcp gen1_2d.pth
# Processing file 1xUbH2tygLPTHpuI0AAjfFnRW_F77g6rE gen2_8d_lb.pth
# Processing file 1fY2l4NreJHSeummDvF0J1cfHQjES0gG_ oracle_2d.pth
# Processing file 1PtIK0HhffZphelVXojMWJBpIBAnKhMBQ pairs_2d.pt
# Processing file 1FomNGw_NcCvfCb5ENbkgGKYjL-Ifp-hq rot_bin_te.pt
# Processing file 1Kl4nfjJOIkAAB8ZN0Mr8YG9908N9gbRs rot_bin_tr.pt
# Processing file 1KM6eC79qW82ehBagzJutY-tebRDHchEF rot_full_te.pt
# Processing file 1DbLX2faINLvxg-InDm2NHI97a3B184o6 rot_full_tr.pt
# Processing file 19BYE869-FAlsHSXcrBY_S_e9QiuCQaPy rot_mlp_2d.pth
# Processing file 10WpqTYYBbG5AHNGRWMU0o8xxTHGiyxpF vae_2d.pth
# Processing file 1inK4JYoLqalSXkzIDalE3IqAUeCSXiUp vae_8d_lb.pth
# Processing file 1NwN81EV-wn_09kF_hdoYymAhGN4sk4zL z2_te.pt
# Processing file 1FmIZ82M07ZwquTVJSvFJkm3HKpG6joLy z2_tr.pt
# Processing file 1F3hI6UtaPnuBJnfyzYjo4Ch03kbVGm2E z8_lb_te.pt
# Processing file 1Q3cGhE9mgXMwrHutqWfMARRsa9APQuNn z8_lb_tr.pt
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1rG1DICUX-DPshGi3A5XB0GhwKYTEwx4K
# To: /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/checkpoints/clf10_8d_lb.pth
# 100%|██████████| 110k/110k [00:00<00:00, 348kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Gb7hedTwVnGTXgNITmp2Em3Tjr52rIcp
# To: /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/checkpoints/gen1_2d.pth
# 100%|██████████| 71.0k/71.0k [00:00<00:00, 212kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1xUbH2tygLPTHpuI0AAjfFnRW_F77g6rE
# To: /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/checkpoints/gen2_8d_lb.pth
# 100%|██████████| 77.5k/77.5k [00:00<00:00, 189kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1fY2l4NreJHSeummDvF0J1cfHQjES0gG_
# To: /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/checkpoints/oracle_2d.pth
# 100%|██████████| 104k/104k [00:00<00:00, 255kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1PtIK0HhffZphelVXojMWJBpIBAnKhMBQ
# To: /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/checkpoints/pairs_2d.pt
# 100%|██████████| 2.43M/2.43M [00:01<00:00, 1.86MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1FomNGw_NcCvfCb5ENbkgGKYjL-Ifp-hq
# From (redirected): https://drive.google.com/uc?id=1FomNGw_NcCvfCb5ENbkgGKYjL-Ifp-hq&confirm=t&uuid=a1e51c2a-617b-4d8d-aba1-14ff79d21fe4
# To: /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/checkpoints/rot_bin_te.pt
# 100%|██████████| 80.0M/80.0M [00:08<00:00, 8.99MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1Kl4nfjJOIkAAB8ZN0Mr8YG9908N9gbRs
# From (redirected): https://drive.google.com/uc?id=1Kl4nfjJOIkAAB8ZN0Mr8YG9908N9gbRs&confirm=t&uuid=1d7581fd-00b7-447e-b71c-e87b34a3b3e7
# To: /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/checkpoints/rot_bin_tr.pt
# 100%|██████████| 479M/479M [00:23<00:00, 20.5MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1KM6eC79qW82ehBagzJutY-tebRDHchEF
# From (redirected): https://drive.google.com/uc?id=1KM6eC79qW82ehBagzJutY-tebRDHchEF&confirm=t&uuid=737c9379-6115-4df2-89fc-a5271011e313
# To: /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/checkpoints/rot_full_te.pt
# 100%|██████████| 378M/378M [00:43<00:00, 8.64MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1DbLX2faINLvxg-InDm2NHI97a3B184o6
# From (redirected): https://drive.google.com/uc?id=1DbLX2faINLvxg-InDm2NHI97a3B184o6&confirm=t&uuid=d2a74fa1-66fa-4464-ba4c-6975d16c7120
# To: /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/checkpoints/rot_full_tr.pt
# 100%|██████████| 2.27G/2.27G [01:41<00:00, 22.4MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=19BYE869-FAlsHSXcrBY_S_e9QiuCQaPy
# To: /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/checkpoints/rot_mlp_2d.pth
# 100%|██████████| 138k/138k [00:00<00:00, 422kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=10WpqTYYBbG5AHNGRWMU0o8xxTHGiyxpF
# To: /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/checkpoints/vae_2d.pth
# 100%|██████████| 3.56M/3.56M [00:04<00:00, 863kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1inK4JYoLqalSXkzIDalE3IqAUeCSXiUp
# To: /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/checkpoints/vae_8d_lb.pth
# 100%|██████████| 3.85M/3.85M [00:00<00:00, 4.52MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1NwN81EV-wn_09kF_hdoYymAhGN4sk4zL
# To: /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/checkpoints/z2_te.pt
# 100%|██████████| 611k/611k [00:00<00:00, 1.16MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1FmIZ82M07ZwquTVJSvFJkm3HKpG6joLy
# To: /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/checkpoints/z2_tr.pt
# 100%|██████████| 3.65M/3.65M [00:00<00:00, 3.79MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1F3hI6UtaPnuBJnfyzYjo4Ch03kbVGm2E
# To: /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/checkpoints/z8_lb_te.pt
# 100%|██████████| 5.76M/5.76M [00:01<00:00, 5.21MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1Q3cGhE9mgXMwrHutqWfMARRsa9APQuNn
# From (redirected): https://drive.google.com/uc?id=1Q3cGhE9mgXMwrHutqWfMARRsa9APQuNn&confirm=t&uuid=24ac6d95-e3ab-4304-935c-c532fffa00d8
# To: /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/checkpoints/z8_lb_tr.pt
# 100%|██████████| 34.6M/34.6M [00:02<00:00, 14.6MB/s]
# ✅ Download complete.
# Using device: cuda
# Download completed

# %% [markdown]
# ## Task 1 - Dataset Preparation & VAE Training
#
# **Objective**: Rotate every MNIST sample in steps of 30 deg (12 orientations per image), build and train a VAE with a low-dimensional latent space.
#
# ### Hyperparameters
# Modify any values here before running the VAE training!

# %%
# --- Task 1 Hyperparameters ---
ROTATION_STEP = 30
LATENT_DIM = 2
VAE_EPOCHS = 100
VAE_LR = 1e-3
VAE_BETA_MAX = 1.0
VAE_BETA_WARMUP = 10
BATCH_SIZE = 128

# %%
print("Loading and rotating MNIST (digits 0-1)...")
train_bin, test_bin = load_data(max_digit=1, tag="rot_bin")
tr_ld = make_loader(train_bin, bs=BATCH_SIZE)
te_ld = make_loader(test_bin, bs=BATCH_SIZE, sh=False)

print(f"Train size: {len(train_bin['images'])}, Test size: {len(test_bin['images'])}")
# Out:
# Loading and rotating MNIST (digits 0-1)...
#   loading cached rot_bin
# Train size: 151980, Test size: 25380

# %%
visualise_rotated_samples(train_bin, test_bin)
# Out:
#   saved figure: /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/figures/task1_rotated_samples.png

# %%
# Train / load the binary VAE (digits 0-1)
vae = train_vae(tr_ld, te_ld, latent_dim=LATENT_DIM,
                epochs=VAE_EPOCHS, lr=VAE_LR,
                beta_warmup=VAE_BETA_WARMUP, beta_max=VAE_BETA_MAX,
                name=f"vae_{LATENT_DIM}d")

z_train = encode_dataset(vae, tr_ld, f"z{LATENT_DIM}_tr")
z_test  = encode_dataset(vae, te_ld, f"z{LATENT_DIM}_te")
# Out:
#   loading VAE from /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/checkpoints/vae_2d.pth
#   loading latent codes from /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/checkpoints/z2_tr.pt
#   loading latent codes from /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/checkpoints/z2_te.pt

# %%
visualise_latent_space(z_train, z_test)
visualise_reconstructions(vae, test_bin)
# Out:
#   saved figure: /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/figures/task1_latent_space.png
#   saved figure: /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/figures/task1_reconstructions.png

# %% [markdown]
# ## Task 2 - Supervised Symmetry Discovery
#
# **Objective**: Learn an MLP that maps z -> z' corresponding to the known 30 deg rotation.
# Apply iteratively to trace a full orbit.
#
# ### Hyperparameters

# %%
# --- Task 2 Hyperparameters ---
MLP_EPOCHS = 200
MLP_LR = 1e-3
MLP_BATCH_SIZE = 256
MLP_HIDDEN = 128

# %%
rot_mlp = train_rotation_mlp(z_train, 
                             latent_dim=LATENT_DIM, 
                             epochs=MLP_EPOCHS,
                             lr=MLP_LR,
                             batch_size=MLP_BATCH_SIZE,
                             name=f"rot_mlp_{LATENT_DIM}d")

visualise_supervised(vae, rot_mlp, z_test)
# Out:
#   loading RotationMLP from /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/checkpoints/rot_mlp_2d.pth
#   saved figure: /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/figures/task2_supervised_iterative_rotation.png

# %%
visualise_rotation_trajectories(rot_mlp, z_test)
# Out:
#   saved figure: /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/figures/task2_rotation_trajectories.png

# %% [markdown]
# ## Task 3a - Unsupervised Symmetry Discovery (binary 0/1)
#
# **Objective**: Discover transformations G(z) that preserve classifier logits while strictly moving.
#
# ### Hyperparameters

# %%
# --- Task 3a Hyperparameters ---
CLF_EPOCHS = 200
CLF_LR = 1e-3

GEN_EPOCHS = 800
GEN_LR = 2e-3
GEN_EPS = 1e-4
GEN_NORM_WEIGHT = 1.0

# %%
clf_bin = train_classifier(
    z_train["z"], z_train["y"], z_test["z"], z_test["y"],
    latent_dim=LATENT_DIM, num_classes=1, epochs=CLF_EPOCHS, lr=CLF_LR,
    name=f"oracle_{LATENT_DIM}d")

gen_bin = train_symmetry_generator(
    clf_bin, z_train, latent_dim=LATENT_DIM,
    epochs=GEN_EPOCHS, eps=GEN_EPS, norm_weight=GEN_NORM_WEIGHT, lr=GEN_LR,
    name=f"gen1_{LATENT_DIM}d")

visualise_unsupervised(vae, gen_bin, z_test, total_steps=25000, n_show=10,
                       title="Task 3a: Unsupervised symmetry (0-1)",
                       fig_name="task3a_unsupervised_symmetry_01.png")

plot_symmetry_paths(gen_bin, z_test, steps=25000, record_every=100,
                    title="Task 3a: Symmetry paths (binary 0/1)",
                    fig_name="task3a_symmetry_paths_01.png")
# Out:
#   loading classifier from /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/checkpoints/oracle_2d.pth
#   loading generator from /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/checkpoints/gen1_2d.pth
#   saved figure: /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/figures/task3a_unsupervised_symmetry_01.png
#   saved figure: /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/figures/task3a_symmetry_paths_01.png

# %% [markdown]
# ## Task 3b - Unsupervised Symmetry Discovery (full 0-9)
#
# **Objective**: Extended to all 10 digits. We use a higher-dimensional latent space (8D).
#
# ### Hyperparameters

# %%
# --- Task 3b Hyperparameters ---
LATENT_FULL = 8
VAE_EPOCHS_FULL = 150
VAE_BETA_FULL = 0.01

CLF_EPOCHS_FULL = 200
GEN_EPOCHS_FULL = 800
GEN_EPS_FULL = 1e-4
GEN_NORM_WEIGHT_FULL = 1.0

# %%
from sklearn.decomposition import PCA

print("Loading full MNIST (0-9)...")
train_full, test_full = load_data(max_digit=None, tag="rot_full")
tr_full_ld = make_loader(train_full, bs=BATCH_SIZE)
te_full_ld = make_loader(test_full, bs=BATCH_SIZE, sh=False)

# Low β to preserve latent structure for downstream symmetry discovery
vae_full = train_vae(tr_full_ld, te_full_ld, latent_dim=LATENT_FULL,
                     epochs=VAE_EPOCHS_FULL, beta_max=VAE_BETA_FULL, 
                     name=f"vae_{LATENT_FULL}d_lb")

z_train_full = encode_dataset(vae_full, tr_full_ld, f"z{LATENT_FULL}_lb_tr")
z_test_full  = encode_dataset(vae_full, te_full_ld, f"z{LATENT_FULL}_lb_te")

clf_full = train_classifier(
    z_train_full["z"], z_train_full["y"],
    z_test_full["z"], z_test_full["y"],
    latent_dim=LATENT_FULL, num_classes=10, epochs=CLF_EPOCHS_FULL,
    name=f"clf10_{LATENT_FULL}d_lb")

gen_full = train_symmetry_generator(
    clf_full, z_train_full, latent_dim=LATENT_FULL,
    epochs=GEN_EPOCHS_FULL, eps=GEN_EPS_FULL, norm_weight=GEN_NORM_WEIGHT_FULL,
    name=f"gen2_{LATENT_FULL}d_lb")
# Out:
# Loading full MNIST (0-9)...
#   loading cached rot_full
#   loading VAE from /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/checkpoints/vae_8d_lb.pth
#   loading latent codes from /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/checkpoints/z8_lb_tr.pt
#   loading latent codes from /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/checkpoints/z8_lb_te.pt
#   loading classifier from /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/checkpoints/clf10_8d_lb.pth
#   loading generator from /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/checkpoints/gen2_8d_lb.pth

# %%
visualise_reconstructions_full(vae_full, test_full)
# Out:
#   saved figure: /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/figures/task3b_reconstructions_full.png

# %%
visualise_unsupervised(vae_full, gen_full, z_test_full, total_steps=25000,
                       n_show=10, n_rows=5,
                       title="Task 3b: Unsupervised symmetry (0-9)",
                       fig_name="task3b_unsupervised_symmetry_09.png")

# Symmetry paths projected to PCA space
if show_cached_figure("task3b_symmetry_paths_pca_09.png",
                      title="Task 3b: Symmetry paths in PCA space (0-9)",
                      figsize=(10, 10)):
    pass
else:
    gen_full.eval()
    fig, ax = plt.subplots(figsize=(10, 10))
    # Fit PCA
    pca = PCA(n_components=2).fit(z_test_full["z"].numpy())
    z2d = pca.transform(z_test_full["z"].numpy())
    
    ax.scatter(z2d[:, 0], z2d[:, 1], c=z_test_full["y"].numpy(),
               s=0.5, alpha=0.15, cmap="tab10")

    tab10_colors = plt.cm.tab10(np.linspace(0, 1, 10))
    for lbl in range(10):
        mask = (z_test_full["y"] == lbl) & (z_test_full["angle"] == 0)
        idx = mask.nonzero(as_tuple=True)[0]
        if len(idx) == 0: continue
        
        current = z_test_full["z"][idx[0]].unsqueeze(0).to(DEVICE)
        raw_path = [current.cpu().numpy().squeeze()]
        for i in range(1, 25001):
            with torch.no_grad():
                current = gen_full(current)
            if i % 100 == 0:
                raw_path.append(current.cpu().numpy().squeeze())
        
        raw_path = np.array(raw_path)
        path_2d = pca.transform(raw_path)
        ax.plot(path_2d[:, 0], path_2d[:, 1], color=tab10_colors[lbl], linewidth=1, alpha=0.8)
        ax.plot(path_2d[0, 0], path_2d[0, 1], "o", color=tab10_colors[lbl], markersize=6)

    ax.set(title="Task 3b: Symmetry paths in PCA space (0-9)", xlabel="PC1", ylabel="PC2")
    plt.tight_layout()
    from src.utils import savefig_cached
    savefig_cached(fig, "task3b_symmetry_paths_pca_09.png")
    plt.show()
# Out:
#   saved figure: /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/figures/task3b_unsupervised_symmetry_09.png
#   saved figure: /home/nirbhay/Desktop/ML/Gsoc/gsoc-symmetry-discovery/figures/task3b_symmetry_paths_pca_09.png
